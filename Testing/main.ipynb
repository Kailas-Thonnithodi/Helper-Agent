# %%
from typing import Annotated
from typing_extensions import TypedDict

# langgraph, langchain and langsmith related
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.memory import MemorySaver
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv
from IPython.display import Image, display
import requests
import os

# %%
import gradio
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import gradio
#
# File ~/Github/Personal/Helper-Agent/.venv/lib/python3.13/site-packages/gradio/__init__.py:10
#       8 from gradio.blocks import Blocks
#       9 from gradio.chat_interface import ChatInterface
# ---> 10 from gradio.cli import deploy
#      11 from gradio.components import (
#      12     HTML,
#      13     JSON,
#    (...)     69     component,
#      70 )
#      71 from gradio.components.audio import WaveformOptions
#
# File ~/Github/Personal/Helper-Agent/.venv/lib/python3.13/site-packages/gradio/cli/__init__.py:1
# ----> 1 from .cli import cli, deploy
#       2 from .commands import custom_component, sketch
#       4 __all__ = ["cli", "deploy", "custom_component", "sketch"]
#
# File ~/Github/Personal/Helper-Agent/.venv/lib/python3.13/site-packages/gradio/cli/cli.py:8
#       4 from rich.console import Console
#       6 from gradio import analytics
# ----> 8 from .commands import (
#       9     custom_component,
#      10     deploy,
#      11     hf_login,
#      12     load_app,
#      13     print_environment_info,
#      14     reload,
#      15     sketch,
#      16     upload_mcp,
#      17 )
#      19 app = typer.Typer()
#      20 app.add_typer(load_app, name="load")
#
# File ~/Github/Personal/Helper-Agent/.venv/lib/python3.13/site-packages/gradio/cli/commands/__init__.py:3
#       1 from .cli_env_info import print_environment_info
#       2 from .components import app as custom_component
# ----> 3 from .deploy_space import deploy
#       4 from .hf_login import hf_login
#       5 from .load import load_app
#
# File ~/Github/Personal/Helper-Agent/.venv/lib/python3.13/site-packages/gradio/cli/commands/deploy_space.py:15
#      11 from typer import Option
#      13 import gradio as gr
# ---> 15 repo_directory = os.getcwd()
#      16 readme_file = os.path.join(repo_directory, "README.md")
#      17 github_action_template = os.path.join(
#      18     os.path.dirname(__file__), "deploy_space_action.yaml"
#      19 )
#
# FileNotFoundError: [Errno 2] No such file or directory
